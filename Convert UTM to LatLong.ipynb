# %%
# utm package is for converting utm to lat/long
import utm
import pandas as pd
from time import sleep
from tqdm.notebook import tqdm
# Show all columns, rows on print
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Customize paths to water and veg files as needed
# "ltrm_vegsrs_data.csv"
# "ltrm_water_data.csv"
water_path = r"C:\Users\Doug\Documents\Classes\TDA\ltrm_water_data.csv"
veg_path = r"C:\Users\Doug\Documents\Classes\TDA\ltrm_vegsrs_data.csv"

# Create DataFrames containing ltrm_water and ltrm_vegsrs data
df_water = pd.read_csv(water_path, low_memory=False)
df_veg = pd.read_csv(veg_path, low_memory=False)

# %%
# WATER

# Create a temp-DataFrame only containing 'SHEETBAR', 'LATITUDE', 'LONGITUDE' columns; these will be filled during iteration across DataFrames
# SHEETBAR : Merge key to join lat/long values to their matching sample
# LATITUDE, LONGITUDE : Calculated Latitude/Longitude pair that is derived from UTM EASTING, UTM NORTHING codes
temp_water = pd.DataFrame(columns=['SHEETBAR', 'LATITUDE', 'LONGITUDE'])

# dictionary with counters to track how many rows have missing values
missing_row_count = {'water': 0, 'vegsrs': 0}

for index, row in tqdm(df_water.iterrows()):
    # Base case to check if row is missing EASTING, NORTHING values; if so, print row and iterate missing_row_count, then skip the row
    if pd.isnull(row['EASTING']) or pd.isnull(row['NORTHING']):
        print(row)
        missing_row_count['water'] += 1
        continue
    # UTM ZONE is in Northern Hemisphere, so northern = True
    lat_long_temp = utm.to_latlon(row['EASTING'], row['NORTHING'], row['UTMZONE'], northern=True)
    # Pull values
    latitude_temp = lat_long_temp[0]
    longitude_temp = lat_long_temp[1]
    # Create a dictionary that can be appended to temp with lat, long values
    d = {'SHEETBAR': row['SHEETBAR'], 'LATITUDE': latitude_temp, 'LONGITUDE': longitude_temp}
    # DEBUG : Print the newly created row value
    # print(d, "INDEX:", index)
    temp_water = temp_water.append(d, ignore_index=True)

    
# VEGSRS
# Create a temp-DataFrame only containing 'BARCODE', 'LATITUDE', 'LONGITUDE' columns; these will be filled during iteration across DataFrames
# BARCODE : Merge key to join lat/long values to their matching sample
# LATITUDE, LONGITUDE : Calculated Latitude/Longitude pair that is derived from EAST1, NORTH1 codes
temp_veg = pd.DataFrame(columns=['BARCODE', 'LATITUDE', 'LONGITUDE'])

for index, row in tqdm(df_veg.iterrows()):
    # Base case to check if row is missing EASTING, NORTHING values; if so, print row and iterate missing_row_count, then skip the row
    if pd.isnull(row['EAST1']) or pd.isnull(row['NORTH1']):
        print(row)
        missing_row_count['vegsrs'] += 1
        continue
    # UTM ZONE is in Northern Hemisphere, so northern = True
    lat_long_temp = utm.to_latlon(row['EAST1'], row['NORTH1'], row['ZONE'], northern=True)
    # Pull values
    latitude_temp = lat_long_temp[0]
    longitude_temp = lat_long_temp[1]
    # Create a dictionary that can be appended to temp with lat, long values
    d = {'BARCODE': row['BARCODE'], 'LATITUDE': latitude_temp, 'LONGITUDE': longitude_temp}
    # DEBUG : Print the newly created row value
    # print(d, "INDEX:", index)
    temp_veg = temp_veg.append(d, ignore_index=True)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# SHEETBAR       44011540
# FLDNUM                4
# DATE         07/26/2004
# TIME              11:12
# NSAMPLES              2
# PROJCD               M-
# LOCATCD         0442037
# DATABLCK            NaN
# WAVHI               NaN
# WAVEHIQF            NaN
# WDP                1.05
# ZMAX               1.05
# ZMAXQF              NaN
# SECCHI               15
# SECCHIQF            NaN
# WAVCD                 1
# ZICE                NaN
# ZICEQF              NaN
# ZSICE               NaN
# ZSICEQF             NaN
# PICE                NaN
# PICEQF              NaN
# ZSNOW               NaN
# ZSNOWQF             NaN
# PSNOW               NaN
# PSNOWQF             NaN
# SITETYPE              0
# STRATUM               5
# SUMCD               NaN
# SBSTRATE              2
# VEGCOVER              0
# VEGDENS             NaN
# VEGTYPE             NaN
# METHOD                1
# UTMZONE              15
# NORTHING            NaN
# EASTING             NaN
# GRIDCODE            NaN
# Z15NORTH            NaN
# Z15EAST             NaN
# FLDEAST             NaN
# FLDNORTH            NaN
# DRVEAST             NaN
# DRVNORTH            NaN
# ACCURACY            NaN
# SAMPTYPE            NaN
# STAGE               NaN
# RCRDCODE            104
# LDRCODE             104
# ROWNUM                1
# Z                   0.2
# ZQF                 NaN
# SAMPZCD             NaN
# CALCZCD              SF
# TEMP               22.9
# TEMPQF              NaN
# DO                  9.4
# DOQF                NaN
# PH                  8.6
# PHQF                NaN
# TURB                 76
# TURBQF              NaN
# COND                422
# CONDQF              NaN
# VEL                0.05
# VELQF               NaN
# DIR                 127
# DIRQF               NaN
# SMPLBAR     4.40115e+07
# SNPCODE             NaN
# NOXCODE               1
# METCODE             NaN
# CLCODE                1
# SSCODE                1
# CHSCODE             NaN
# CHFCODE               1
# PYTCODE             NaN
# TNPCODE               1
# RPTCODE             NaN
# SRP               0.016
# SRPQF                 0
# TSP                 NaN
# TSPQF               NaN
# TP                0.264
# TPQF                  0
# TN                2.843
# TNQF                  0
# TSN                 NaN
# TSNQF               NaN
# SS                 73.4
# SSQF                  0
# ORG                 NaN
# ORGQF               NaN
# CHLS                NaN
# CHLSQF              NaN
# PHAEO               NaN
# PHAEOQF             NaN
# NHX               0.081
# NHXQF                 0
# NOX               0.929
# NOXQF                 0
# SI                4.355
# SIQF                128
# CA                  NaN
# CAQF                NaN
# FE                  NaN
# FEQF                NaN
# MN                  NaN
# MNQF                NaN
# K                   NaN
# KQF                 NaN
# CL                  NaN
# CLQF                NaN
# VSS                19.1
# VSS_QF                0
# CHLF              121.1
# CHLFQF                0
# CHLFI               NaN
# CHLFIQF             NaN
# NA                  NaN
# NAQF                NaN
# MG                  NaN
# MGQF                NaN
# SO4                 NaN
# SO4QF               NaN
# HABCLASS            NaN
# INSTCODE          38261
# LINKBAR             NaN
# RAWNTU               76
# RAWNTUQF            NaN
# CHLcal          111.645
# Name: 51169, dtype: object
# SHEETBAR      44011540
# FLDNUM               4
# DATE        07/26/2004
# TIME             11:12
# NSAMPLES             2
# PROJCD              M-
# LOCATCD        0442037
# DATABLCK           NaN
# WAVHI              NaN
# WAVEHIQF           NaN
# WDP               1.05
# ZMAX              1.05
# ZMAXQF             NaN
# SECCHI              15
# SECCHIQF           NaN
# WAVCD                1
# ZICE               NaN
# ZICEQF             NaN
# ZSICE              NaN
# ZSICEQF            NaN
# PICE               NaN
# PICEQF             NaN
# ZSNOW              NaN
# ZSNOWQF            NaN
# PSNOW              NaN
# PSNOWQF            NaN
# SITETYPE             0
# STRATUM              5
# SUMCD              NaN
# SBSTRATE             2
# VEGCOVER             0
# VEGDENS            NaN
# VEGTYPE            NaN
# METHOD               1
# UTMZONE             15
# NORTHING           NaN
# EASTING            NaN
# GRIDCODE           NaN
# Z15NORTH           NaN
# Z15EAST            NaN
# FLDEAST            NaN
# FLDNORTH           NaN
# DRVEAST            NaN
# DRVNORTH           NaN
# ACCURACY           NaN
# SAMPTYPE           NaN
# STAGE              NaN
# RCRDCODE           104
# LDRCODE            104
# ROWNUM               2
# Z                 0.85
# ZQF                NaN
# SAMPZCD            NaN
# CALCZCD             BT
# TEMP              21.4
# TEMPQF             NaN
# DO                   6
# DOQF               NaN
# PH                 8.3
# PHQF               NaN
# TURB               NaN
# TURBQF               X
# COND               430
# CONDQF             NaN
# VEL                NaN
# VELQF                X
# DIR                NaN
# DIRQF                X
# SMPLBAR            NaN
# SNPCODE            NaN
# NOXCODE            NaN
# METCODE            NaN
# CLCODE             NaN
# SSCODE             NaN
# CHSCODE            NaN
# CHFCODE            NaN
# PYTCODE            NaN
# TNPCODE            NaN
# RPTCODE            NaN
# SRP                NaN
# SRPQF              NaN
# TSP                NaN
# TSPQF              NaN
# TP                 NaN
# TPQF               NaN
# TN                 NaN
# TNQF               NaN
# TSN                NaN
# TSNQF              NaN
# SS                 NaN
# SSQF               NaN
# ORG                NaN
# ORGQF              NaN
# CHLS               NaN
# CHLSQF             NaN
# PHAEO              NaN
# PHAEOQF            NaN
# NHX                NaN
# NHXQF              NaN
# NOX                NaN
# NOXQF              NaN
# SI                 NaN
# SIQF               NaN
# CA                 NaN
# CAQF               NaN
# FE                 NaN
# FEQF               NaN
# MN                 NaN
# MNQF               NaN
# K                  NaN
# KQF                NaN
# CL                 NaN
# CLQF               NaN
# VSS                NaN
# VSS_QF             NaN
# CHLF               NaN
# CHLFQF             NaN
# CHLFI              NaN
# CHLFIQF            NaN
# NA                 NaN
# NAQF               NaN
# MG                 NaN
# MGQF               NaN
# SO4                NaN
# SO4QF              NaN
# HABCLASS           NaN
# INSTCODE         38261
# LINKBAR            NaN
# RAWNTU             NaN
# RAWNTUQF             X
# CHLcal             NaN
# Name: 51170, dtype: object
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# BARCODE        32003525
# ROWNUM                2
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 08
# DATE         07/22/1999
# LDRCODE             333
# RCRDCODE            333
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD              301
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M688
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD              NaN
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           640855
# NORTH_U         4839362
# GRIDCODE        64085.8
# EAST_15          640834
# NORTH_15    4.83937e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           9901
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 319, dtype: object
# BARCODE        32008991
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 08
# DATE         07/17/2007
# LDRCODE             333
# RCRDCODE            369
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD              216
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M697
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           638004
# NORTH_U         4851212
# GRIDCODE            NaN
# EAST_15          638004
# NORTH_15    4.85121e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2603
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 1260, dtype: object
# BARCODE        32008992
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 08
# DATE         07/17/2007
# LDRCODE             333
# RCRDCODE            369
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD              217
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M697
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           638354
# NORTH_U         4851062
# GRIDCODE            NaN
# EAST_15          638354
# NORTH_15    4.85106e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2603
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 1261, dtype: object
# BARCODE        32005851
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 08
# DATE         07/08/2002
# LDRCODE             333
# RCRDCODE            334
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD              351
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M693
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           639905
# NORTH_U         4845962
# GRIDCODE            NaN
# EAST_15          639905
# NORTH_15    4.84596e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2201
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 2086, dtype: object
# BARCODE        32006814
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 08
# DATE         06/26/2003
# LDRCODE             333
# RCRDCODE            333
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD              239
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M693
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           644005
# NORTH_U         4845912
# GRIDCODE            NaN
# EAST_15          644005
# NORTH_15    4.84591e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2301
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 2147, dtype: object
# BARCODE        32003383
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 08
# DATE         07/14/1999
# LDRCODE             333
# RCRDCODE            333
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD              277
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M691
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD              NaN
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           641405
# NORTH_U         4843412
# GRIDCODE        64150.8
# EAST_15          641461
# NORTH_15    4.84341e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           9901
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 3118, dtype: object
# BARCODE        32006421
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 07
# DATE         08/20/2002
# LDRCODE             333
# RCRDCODE            333
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD              252
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M705
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           633406
# NORTH_U         4863134
# GRIDCODE            NaN
# EAST_15          633406
# NORTH_15    4.86313e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2201
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 3612, dtype: object
# BARCODE        32006327
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 07
# DATE         08/28/2002
# LDRCODE             333
# RCRDCODE             98
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD              158
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M708
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           634156
# NORTH_U         4865484
# GRIDCODE            NaN
# EAST_15          634156
# NORTH_15    4.86548e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2201
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 5077, dtype: object
# BARCODE        32006333
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 07
# DATE         08/21/2002
# LDRCODE             333
# RCRDCODE            334
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD              164
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M707
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           632456
# NORTH_U         4865284
# GRIDCODE            NaN
# EAST_15          632456
# NORTH_15    4.86528e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2201
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 5090, dtype: object
# BARCODE        32006336
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 07
# DATE         08/21/2002
# LDRCODE             333
# RCRDCODE            333
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD              167
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M707
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           633556
# NORTH_U         4865134
# GRIDCODE            NaN
# EAST_15          633556
# NORTH_15    4.86513e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2201
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 5100, dtype: object
# BARCODE        32006237
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 07
# DATE         08/06/2002
# LDRCODE             333
# RCRDCODE            333
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD               68
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M710
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           630456
# NORTH_U         4869184
# GRIDCODE            NaN
# EAST_15          630456
# NORTH_15    4.86918e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2201
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 6357, dtype: object
# BARCODE        32006244
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 07
# DATE         08/06/2002
# LDRCODE             333
# RCRDCODE            333
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD               75
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M711
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           630006
# NORTH_U         4868634
# GRIDCODE            NaN
# EAST_15          630006
# NORTH_15    4.86863e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2201
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 6381, dtype: object
# BARCODE        32006279
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 07
# DATE         08/08/2002
# LDRCODE             333
# RCRDCODE            333
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD              110
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M709
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           631206
# NORTH_U         4866884
# GRIDCODE            NaN
# EAST_15          631206
# NORTH_15    4.86688e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2201
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 6426, dtype: object
# BARCODE        32006281
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 07
# DATE         08/27/2002
# LDRCODE             333
# RCRDCODE             98
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD              112
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M708
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           633906
# NORTH_U         4866734
# GRIDCODE            NaN
# EAST_15          633906
# NORTH_15    4.86673e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2201
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 6429, dtype: object
# BARCODE       32003080
# ROWNUM               2
# PAGENUM              1
# FLDNUM               2
# PROJCD           M-98A
# POOL                08
# DATE        06/28/1999
# LDRCODE            333
# RCRDCODE           214
# DETRITUS           NaN
# SBSTRATE           NaN
# SITECD             271
# MSTRATUM           BWC
# ASTRATUM           NaN
# RIVMILE           M692
# VEG_S              NaN
# VEG_RF             NaN
# VEG_E              NaN
# VEG_A              NaN
# VEG_NRF            NaN
# VEG_U              NaN
# COV_NRF            NaN
# COV_RF             NaN
# COV_E              NaN
# EAST1              NaN
# NORTH1             NaN
# ZONE                15
# ACCUR1             NaN
# METHOD             NaN
# EAST2              NaN
# NORTH2             NaN
# ACCUR2             NaN
# ZONE_U              15
# EAST_U          644005
# NORTH_U        4845162
# GRIDCODE       64405.8
# EAST_15         644030
# NORTH_15    4.8452e+06
# HABITAT1           NaN
# HABITAT2           NaN
# HABITAT3           NaN
# HABITAT4           NaN
# HABITAT5           NaN
# HABITAT6           NaN
# DEPTH1             NaN
# DEPTH2             NaN
# DEPTH3             NaN
# DEPTH4             NaN
# DEPTH5             NaN
# DEPTH6             NaN
# DENSITY1           NaN
# DENSITY2           NaN
# DENSITY3           NaN
# DENSITY4           NaN
# DENSITY5           NaN
# DENSITY6           NaN
# BATCHNUM          9901
# SPPCD           NOSMPL
# VISUAL1              0
# VISUAL2              0
# VISUAL3              0
# VISUAL4              0
# VISUAL5              0
# VISUAL6              0
# RAKE1                1
# RAKE2                1
# RAKE3                1
# RAKE4                1
# RAKE5                1
# RAKE6                1
# ADDSPP             NaN
# COVSPP             NaN
# QECODE             NaN
# VOUCHER            NaN
# Name: 7346, dtype: object
# BARCODE        32006230
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 07
# DATE         08/06/2002
# LDRCODE             333
# RCRDCODE            333
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD               61
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M710
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           630356
# NORTH_U         4869484
# GRIDCODE            NaN
# EAST_15          630356
# NORTH_15    4.86948e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2201
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 7915, dtype: object
# BARCODE        32006231
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 07
# DATE         08/06/2002
# LDRCODE             333
# RCRDCODE            333
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD               62
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M710
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           629956
# NORTH_U         4869384
# GRIDCODE            NaN
# EAST_15          629956
# NORTH_15    4.86938e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2201
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 7916, dtype: object
# BARCODE        32008545
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 08
# DATE         07/19/2006
# LDRCODE             333
# RCRDCODE            333
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD              220
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M697
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           638555
# NORTH_U         4851112
# GRIDCODE            NaN
# EAST_15          638555
# NORTH_15    4.85111e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2601
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 8330, dtype: object
# BARCODE        32008546
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 08
# DATE         07/06/2006
# LDRCODE             333
# RCRDCODE            369
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD              221
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M690
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           639755
# NORTH_U         4845912
# GRIDCODE            NaN
# EAST_15          639755
# NORTH_15    4.84591e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2601
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 8331, dtype: object
# BARCODE       32002397
# ROWNUM               1
# PAGENUM              1
# FLDNUM               2
# PROJCD           M-98A
# POOL                08
# DATE        07/13/1998
# LDRCODE            333
# RCRDCODE           333
# DETRITUS           NaN
# SBSTRATE           NaN
# SITECD             289
# MSTRATUM           BWC
# ASTRATUM           NaN
# RIVMILE           M689
# VEG_S              NaN
# VEG_RF             NaN
# VEG_E              NaN
# VEG_A              NaN
# VEG_NRF            NaN
# VEG_U              NaN
# COV_NRF            NaN
# COV_RF             NaN
# COV_E              NaN
# EAST1              NaN
# NORTH1             NaN
# ZONE                15
# ACCUR1             NaN
# METHOD             NaN
# EAST2              NaN
# NORTH2             NaN
# ACCUR2             NaN
# ZONE_U              15
# EAST_U          642205
# NORTH_U        4840862
# GRIDCODE           NaN
# EAST_15            NaN
# NORTH_15           NaN
# HABITAT1           NaN
# HABITAT2           NaN
# HABITAT3           NaN
# HABITAT4           NaN
# HABITAT5           NaN
# HABITAT6           NaN
# DEPTH1             NaN
# DEPTH2             NaN
# DEPTH3             NaN
# DEPTH4             NaN
# DEPTH5             NaN
# DEPTH6             NaN
# DENSITY1           NaN
# DENSITY2           NaN
# DENSITY3           NaN
# DENSITY4           NaN
# DENSITY5           NaN
# DENSITY6           NaN
# BATCHNUM          9803
# SPPCD           NOSMPL
# VISUAL1              0
# VISUAL2              0
# VISUAL3              0
# VISUAL4              0
# VISUAL5              0
# VISUAL6              0
# RAKE1                1
# RAKE2                1
# RAKE3                1
# RAKE4                1
# RAKE5                1
# RAKE6                1
# ADDSPP             NaN
# COVSPP             NaN
# QECODE             NaN
# VOUCHER            NaN
# Name: 10016, dtype: object
# BARCODE       32002398
# ROWNUM               1
# PAGENUM              1
# FLDNUM               2
# PROJCD           M-98A
# POOL                08
# DATE        07/13/1998
# LDRCODE            333
# RCRDCODE           333
# DETRITUS           NaN
# SBSTRATE           NaN
# SITECD             290
# MSTRATUM           BWC
# ASTRATUM           NaN
# RIVMILE           M689
# VEG_S              NaN
# VEG_RF             NaN
# VEG_E              NaN
# VEG_A              NaN
# VEG_NRF            NaN
# VEG_U              NaN
# COV_NRF            NaN
# COV_RF             NaN
# COV_E              NaN
# EAST1              NaN
# NORTH1             NaN
# ZONE                15
# ACCUR1             NaN
# METHOD             NaN
# EAST2              NaN
# NORTH2             NaN
# ACCUR2             NaN
# ZONE_U              15
# EAST_U          642205
# NORTH_U        4840762
# GRIDCODE           NaN
# EAST_15            NaN
# NORTH_15           NaN
# HABITAT1           NaN
# HABITAT2           NaN
# HABITAT3           NaN
# HABITAT4           NaN
# HABITAT5           NaN
# HABITAT6           NaN
# DEPTH1             NaN
# DEPTH2             NaN
# DEPTH3             NaN
# DEPTH4             NaN
# DEPTH5             NaN
# DEPTH6             NaN
# DENSITY1           NaN
# DENSITY2           NaN
# DENSITY3           NaN
# DENSITY4           NaN
# DENSITY5           NaN
# DENSITY6           NaN
# BATCHNUM          9803
# SPPCD           NOSMPL
# VISUAL1              0
# VISUAL2              0
# VISUAL3              0
# VISUAL4              0
# VISUAL5              0
# VISUAL6              0
# RAKE1                1
# RAKE2                1
# RAKE3                1
# RAKE4                1
# RAKE5                1
# RAKE6                1
# ADDSPP             NaN
# COVSPP             NaN
# QECODE             NaN
# VOUCHER            NaN
# Name: 10017, dtype: object
# BARCODE        32006187
# ROWNUM                1
# PAGENUM               1
# FLDNUM                2
# PROJCD            M-98A
# POOL                 07
# DATE         08/05/2002
# LDRCODE             333
# RCRDCODE            333
# DETRITUS            NaN
# SBSTRATE            NaN
# SITECD               18
# MSTRATUM            BWC
# ASTRATUM            NaN
# RIVMILE            M711
# VEG_S               NaN
# VEG_RF              NaN
# VEG_E               NaN
# VEG_A               NaN
# VEG_NRF             NaN
# VEG_U               NaN
# COV_NRF             NaN
# COV_RF              NaN
# COV_E               NaN
# EAST1               NaN
# NORTH1              NaN
# ZONE                 15
# ACCUR1              NaN
# METHOD                G
# EAST2               NaN
# NORTH2              NaN
# ACCUR2              NaN
# ZONE_U               15
# EAST_U           629456
# NORTH_U         4871384
# GRIDCODE            NaN
# EAST_15          629456
# NORTH_15    4.87138e+06
# HABITAT1            NaN
# HABITAT2            NaN
# HABITAT3            NaN
# HABITAT4            NaN
# HABITAT5            NaN
# HABITAT6            NaN
# DEPTH1              NaN
# DEPTH2              NaN
# DEPTH3              NaN
# DEPTH4              NaN
# DEPTH5              NaN
# DEPTH6              NaN
# DENSITY1            NaN
# DENSITY2            NaN
# DENSITY3            NaN
# DENSITY4            NaN
# DENSITY5            NaN
# DENSITY6            NaN
# BATCHNUM           2201
# SPPCD            NOSMPL
# VISUAL1               0
# VISUAL2               0
# VISUAL3               0
# VISUAL4               0
# VISUAL5               0
# VISUAL6               0
# RAKE1                 1
# RAKE2                 1
# RAKE3                 1
# RAKE4                 1
# RAKE5                 1
# RAKE6                 1
# ADDSPP              NaN
# COVSPP              NaN
# QECODE              NaN
# VOUCHER             NaN
# Name: 10547, dtype: object
# BARCODE       32010342
# ROWNUM               1
# PAGENUM              1
# FLDNUM               2
# PROJCD           M-98A
# POOL                08
# DATE        06/22/2010
# LDRCODE            333
# RCRDCODE           333
# DETRITUS           NaN
# SBSTRATE           NaN
# SITECD             217
# MSTRATUM           BWC
# ASTRATUM           NaN
# RIVMILE           M697
# VEG_S              NaN
# VEG_RF             NaN
# VEG_E              NaN
# VEG_A              NaN
# VEG_NRF            NaN
# VEG_U              NaN
# COV_NRF            NaN
# COV_RF             NaN
# COV_E              NaN
# EAST1              NaN
# NORTH1             NaN
# ZONE                15
# ACCUR1             NaN
# METHOD               G
# EAST2              NaN
# NORTH2             NaN
# ACCUR2             NaN
# ZONE_U              15
# EAST_U          637904
# NORTH_U        4851211
# GRIDCODE           NaN
# EAST_15            NaN
# NORTH_15           NaN
# HABITAT1           NaN
# HABITAT2           NaN
# HABITAT3           NaN
# HABITAT4           NaN
# HABITAT5           NaN
# HABITAT6           NaN
# DEPTH1             NaN
# DEPTH2             NaN
# DEPTH3             NaN
# DEPTH4             NaN
# DEPTH5             NaN
# DEPTH6             NaN
# DENSITY1           NaN
# DENSITY2           NaN
# DENSITY3           NaN
# DENSITY4           NaN
# DENSITY5           NaN
# DENSITY6           NaN
# BATCHNUM          2606
# SPPCD           NOSMPL
# VISUAL1              0
# VISUAL2              0
# VISUAL3              0
# VISUAL4              0
# VISUAL5              0
# VISUAL6              0
# RAKE1                1
# RAKE2                1
# RAKE3                1
# RAKE4                1
# RAKE5                1
# RAKE6                1
# ADDSPP             NaN
# COVSPP             NaN
# QECODE             NaN
# VOUCHER            NaN
# Name: 12856, dtype: object
# BARCODE       32010343
# ROWNUM               1
# PAGENUM              1
# FLDNUM               2
# PROJCD           M-98A
# POOL                08
# DATE        06/22/2010
# LDRCODE            333
# RCRDCODE           333
# DETRITUS           NaN
# SBSTRATE           NaN
# SITECD             218
# MSTRATUM           BWC
# ASTRATUM           NaN
# RIVMILE           M697
# VEG_S              NaN
# VEG_RF             NaN
# ...
# SPPCD           NOAQVG
# VISUAL1              0
# VISUAL2              0
# VISUAL3              0
# VISUAL4              0
# VISUAL5              0
# VISUAL6              0
# RAKE1                1
# RAKE2                1
# RAKE3                1
# RAKE4                1
# RAKE5                1
# RAKE6                1
# ADDSPP             NaN
# COVSPP             NaN
# QECODE             NaN
# VOUCHER            NaN
# Name: 117879, dtype: object
# BARCODE       31006314
# ROWNUM               2
# PAGENUM              1
# FLDNUM               1
# PROJCD           M-02A
# POOL                04
# DATE        07/29/2003
# LDRCODE              1
# RCRDCODE             1
# DETRITUS           NaN
# SBSTRATE           NaN
# SITECD              80
# MSTRATUM          SC-U
# ASTRATUM           NaN
# RIVMILE           M792
# VEG_S              NaN
# VEG_RF             NaN
# VEG_E              NaN
# VEG_A              NaN
# VEG_NRF            NaN
# VEG_U                U
# COV_NRF              0
# COV_RF               0
# COV_E                0
# EAST1              NaN
# NORTH1             NaN
# ZONE                15
# ACCUR1             NaN
# METHOD               X
# EAST2              NaN
# NORTH2             NaN
# ACCUR2             NaN
# ZONE_U              15
# EAST_U          536629
# NORTH_U        4937058
# GRIDCODE           NaN
# EAST_15            NaN
# NORTH_15           NaN
# HABITAT1           NaN
# HABITAT2           NaN
# HABITAT3           NaN
# HABITAT4           NaN
# HABITAT5           NaN
# HABITAT6           NaN
# DEPTH1             NaN
# DEPTH2             NaN
# DEPTH3             NaN
# DEPTH4             NaN
# DEPTH5             NaN
# DEPTH6             NaN
# DENSITY1             0
# DENSITY2             0
# DENSITY3             0
# DENSITY4             0
# DENSITY5             0
# DENSITY6             0
# BATCHNUM          2301
# SPPCD           NOAQVG
# VISUAL1              0
# VISUAL2              0
# VISUAL3              0
# VISUAL4              0
# VISUAL5              0
# VISUAL6              0
# RAKE1                1
# RAKE2                1
# RAKE3                1
# RAKE4                1
# RAKE5                1
# RAKE6                1
# ADDSPP             NaN
# COVSPP             NaN
# QECODE             NaN
# VOUCHER            NaN
# Name: 117881, dtype: object
# BARCODE       31006320
# ROWNUM               1
# PAGENUM              1
# FLDNUM               1
# PROJCD           M-02A
# POOL                04
# DATE        07/30/2003
# LDRCODE              1
# RCRDCODE             1
# DETRITUS           NaN
# SBSTRATE           NaN
# SITECD              86
# MSTRATUM          SC-U
# ASTRATUM           NaN
# RIVMILE           M789
# VEG_S              NaN
# VEG_RF             NaN
# VEG_E              NaN
# VEG_A              NaN
# VEG_NRF            NaN
# VEG_U              NaN
# COV_NRF            NaN
# COV_RF             NaN
# COV_E              NaN
# EAST1              NaN
# NORTH1             NaN
# ZONE                15
# ACCUR1             NaN
# METHOD               X
# EAST2              NaN
# NORTH2             NaN
# ACCUR2             NaN
# ZONE_U              15
# EAST_U          538479
# NORTH_U        4935308
# GRIDCODE           NaN
# EAST_15            NaN
# NORTH_15           NaN
# HABITAT1           NaN
# HABITAT2           NaN
# HABITAT3           NaN
# HABITAT4           NaN
# HABITAT5           NaN
# HABITAT6           NaN
# DEPTH1             NaN
# DEPTH2             NaN
# DEPTH3             NaN
# DEPTH4             NaN
# DEPTH5             NaN
# DEPTH6             NaN
# DENSITY1           NaN
# DENSITY2           NaN
# DENSITY3           NaN
# DENSITY4           NaN
# DENSITY5           NaN
# DENSITY6           NaN
# BATCHNUM          2301
# SPPCD           NOSMPL
# VISUAL1              0
# VISUAL2              0
# VISUAL3              0
# VISUAL4              0
# VISUAL5              0
# VISUAL6              0
# RAKE1                1
# RAKE2                1
# RAKE3                1
# RAKE4                1
# RAKE5                1
# RAKE6                1
# ADDSPP             NaN
# COVSPP             NaN
# QECODE             NaN
# VOUCHER            NaN
# Name: 117887, dtype: object
# BARCODE       31006321
# ROWNUM               2
# PAGENUM              1
# FLDNUM               1
# PROJCD           M-02A
# POOL                04
# DATE        08/01/2003
# LDRCODE              1
# RCRDCODE             1
# DETRITUS           NaN
# SBSTRATE           NaN
# SITECD              87
# MSTRATUM          SC-U
# ASTRATUM           NaN
# RIVMILE           M787
# VEG_S              NaN
# VEG_RF             NaN
# VEG_E              NaN
# VEG_A              NaN
# VEG_NRF            NaN
# VEG_U                U
# COV_NRF              0
# COV_RF               0
# COV_E                0
# EAST1              NaN
# NORTH1             NaN
# ZONE                15
# ACCUR1             NaN
# METHOD               X
# EAST2              NaN
# NORTH2             NaN
# ACCUR2             NaN
# ZONE_U              15
# EAST_U          542779
# NORTH_U        4934958
# GRIDCODE           NaN
# EAST_15            NaN
# NORTH_15           NaN
# HABITAT1           NaN
# HABITAT2           NaN
# HABITAT3           NaN
# HABITAT4           NaN
# HABITAT5           NaN
# HABITAT6           NaN
# DEPTH1             NaN
# DEPTH2             NaN
# DEPTH3             NaN
# DEPTH4             NaN
# DEPTH5             NaN
# DEPTH6             NaN
# DENSITY1             0
# DENSITY2             0
# DENSITY3             0
# DENSITY4             0
# DENSITY5             0
# DENSITY6             0
# BATCHNUM          2301
# SPPCD           NOAQVG
# VISUAL1              0
# VISUAL2              0
# VISUAL3              0
# VISUAL4              0
# VISUAL5              0
# VISUAL6              0
# RAKE1                1
# RAKE2                1
# RAKE3                1
# RAKE4                1
# RAKE5                1
# RAKE6                1
# ADDSPP             NaN
# COVSPP             NaN
# QECODE             NaN
# VOUCHER            NaN
# Name: 117888, dtype: object
# BARCODE       31006322
# ROWNUM               2
# PAGENUM              1
# FLDNUM               1
# PROJCD           M-02A
# POOL                04
# DATE        08/01/2003
# LDRCODE              1
# RCRDCODE             1
# DETRITUS           NaN
# SBSTRATE           NaN
# SITECD              88
# MSTRATUM          SC-U
# ASTRATUM           NaN
# RIVMILE           M787
# VEG_S              NaN
# VEG_RF             NaN
# VEG_E              NaN
# VEG_A              NaN
# VEG_NRF            NaN
# VEG_U                U
# COV_NRF              0
# COV_RF               0
# COV_E                0
# EAST1              NaN
# NORTH1             NaN
# ZONE                15
# ACCUR1             NaN
# METHOD               X
# EAST2              NaN
# NORTH2             NaN
# ACCUR2             NaN
# ZONE_U              15
# EAST_U          542929
# NORTH_U        4934958
# GRIDCODE           NaN
# EAST_15            NaN
# NORTH_15           NaN
# HABITAT1           NaN
# HABITAT2           NaN
# HABITAT3           NaN
# HABITAT4           NaN
# HABITAT5           NaN
# HABITAT6           NaN
# DEPTH1             NaN
# DEPTH2             NaN
# DEPTH3             NaN
# DEPTH4             NaN
# DEPTH5             NaN
# DEPTH6             NaN
# DENSITY1             0
# DENSITY2             0
# DENSITY3             0
# DENSITY4             0
# DENSITY5             0
# DENSITY6             0
# BATCHNUM          2301
# SPPCD           NOAQVG
# VISUAL1              0
# VISUAL2              0
# VISUAL3              0
# VISUAL4              0
# VISUAL5              0
# VISUAL6              0
# RAKE1                1
# RAKE2                1
# RAKE3                1
# RAKE4                1
# RAKE5                1
# RAKE6                1
# ADDSPP             NaN
# COVSPP             NaN
# QECODE             NaN
# VOUCHER            NaN
# Name: 117889, dtype: object
# BARCODE       31006325
# ROWNUM               2
# PAGENUM              1
# FLDNUM               1
# PROJCD           M-02A
# POOL                04
# DATE        07/29/2003
# LDRCODE              1
# RCRDCODE             1
# DETRITUS           NaN
# SBSTRATE           NaN
# SITECD              91
# MSTRATUM          SC-U
# ASTRATUM           NaN
# RIVMILE           M793
# VEG_S              NaN
# VEG_RF             NaN
# VEG_E              NaN
# VEG_A              NaN
# VEG_NRF            NaN
# VEG_U                U
# COV_NRF              0
# COV_RF               0
# COV_E                0
# EAST1              NaN
# NORTH1             NaN
# ZONE                15
# ACCUR1             NaN
# METHOD               X
# EAST2              NaN
# NORTH2             NaN
# ACCUR2             NaN
# ZONE_U              15
# EAST_U          535179
# NORTH_U        4937858
# GRIDCODE           NaN
# EAST_15            NaN
# NORTH_15           NaN
# HABITAT1           NaN
# HABITAT2           NaN
# HABITAT3           NaN
# HABITAT4           NaN
# HABITAT5           NaN
# HABITAT6           NaN
# DEPTH1             NaN
# DEPTH2             NaN
# DEPTH3             NaN
# DEPTH4             NaN
# DEPTH5             NaN
# DEPTH6             NaN
# DENSITY1             0
# DENSITY2             0
# DENSITY3             0
# DENSITY4             0
# DENSITY5             0
# DENSITY6             0
# BATCHNUM          2301
# SPPCD           NOAQVG
# VISUAL1              0
# VISUAL2              0
# VISUAL3              0
# VISUAL4              0
# VISUAL5              0
# VISUAL6              0
# RAKE1                1
# RAKE2                1
# RAKE3                1
# RAKE4                1
# RAKE5                1
# RAKE6                1
# ADDSPP             NaN
# COVSPP             NaN
# QECODE             NaN
# VOUCHER            NaN
# Name: 117892, dtype: object
# BARCODE       31006338
# ROWNUM               2
# PAGENUM              1
# FLDNUM               1
# PROJCD           M-02A
# POOL                04
# DATE        07/30/2003
# LDRCODE              1
# RCRDCODE             1
# DETRITUS           NaN
# SBSTRATE           NaN
# SITECD             104
# MSTRATUM          SC-U
# ASTRATUM           NaN
# RIVMILE           M790
# VEG_S              NaN
# VEG_RF             NaN
# VEG_E              NaN
# VEG_A              NaN
# VEG_NRF            NaN
# VEG_U                U
# COV_NRF              0
# COV_RF               0
# COV_E                0
# EAST1              NaN
# NORTH1             NaN
# ZONE                15
# ACCUR1             NaN
# METHOD               X
# EAST2              NaN
# NORTH2             NaN
# ACCUR2             NaN
# ZONE_U              15
# EAST_U          537829
# NORTH_U        4935508
# GRIDCODE           NaN
# EAST_15            NaN
# NORTH_15           NaN
# HABITAT1           NaN
# HABITAT2           NaN
# HABITAT3           NaN
# HABITAT4           NaN
# HABITAT5           NaN
# HABITAT6           NaN
# DEPTH1             NaN
# DEPTH2             NaN
# DEPTH3             NaN
# DEPTH4             NaN
# DEPTH5             NaN
# DEPTH6             NaN
# DENSITY1             0
# DENSITY2             0
# DENSITY3             0
# DENSITY4             0
# DENSITY5             0
# DENSITY6             0
# BATCHNUM          2301
# SPPCD           NOAQVG
# VISUAL1              0
# VISUAL2              0
# VISUAL3              0
# VISUAL4              0
# VISUAL5              0
# VISUAL6              0
# RAKE1                1
# RAKE2                1
# RAKE3                1
# RAKE4                1
# RAKE5                1
# RAKE6                1
# ADDSPP             NaN
# COVSPP             NaN
# QECODE             NaN
# VOUCHER            NaN
# Name: 117905, dtype: object
# BARCODE       31006339
# ROWNUM               2
# PAGENUM              1
# FLDNUM               1
# PROJCD           M-02A
# POOL                04
# DATE        07/30/2003
# LDRCODE              1
# RCRDCODE             1
# DETRITUS           NaN
# SBSTRATE           NaN
# SITECD             105
# MSTRATUM          SC-U
# ASTRATUM           NaN
# RIVMILE           M789
# VEG_S              NaN
# VEG_RF             NaN
# VEG_E              NaN
# VEG_A              NaN
# VEG_NRF            NaN
# VEG_U                U
# COV_NRF              0
# COV_RF               0
# COV_E                0
# EAST1              NaN
# NORTH1             NaN
# ZONE                15
# ACCUR1             NaN
# METHOD               X
# EAST2              NaN
# NORTH2             NaN
# ACCUR2             NaN
# ZONE_U              15
# EAST_U          538579
# NORTH_U        4935308
# GRIDCODE           NaN
# EAST_15            NaN
# NORTH_15           NaN
# HABITAT1           NaN
# HABITAT2           NaN
# HABITAT3           NaN
# HABITAT4           NaN
# HABITAT5           NaN
# HABITAT6           NaN
# DEPTH1             NaN
# DEPTH2             NaN
# DEPTH3             NaN
# DEPTH4             NaN
# DEPTH5             NaN
# DEPTH6             NaN
# DENSITY1             0
# DENSITY2             0
# DENSITY3             0
# DENSITY4             0
# DENSITY5             0
# DENSITY6             0
# BATCHNUM          2301
# SPPCD           NOAQVG
# VISUAL1              0
# VISUAL2              0
# VISUAL3              0
# VISUAL4              0
# VISUAL5              0
# VISUAL6              0
# RAKE1                1
# RAKE2                1
# RAKE3                1
# RAKE4                1
# RAKE5                1
# RAKE6                1
# ADDSPP             NaN
# COVSPP             NaN
# QECODE             NaN
# VOUCHER            NaN
# Name: 117906, dtype: object
# BARCODE       33011006
# ROWNUM               1
# PAGENUM              1
# FLDNUM               3
# PROJCD           M-98A
# POOL                13
# DATE        07/29/2013
# LDRCODE            501
# RCRDCODE           319
# DETRITUS           NaN
# SBSTRATE           NaN
# SITECD              93
# MSTRATUM            SC
# ASTRATUM           NaN
# RIVMILE           M544
# VEG_S              NaN
# VEG_RF             NaN
# VEG_E              NaN
# VEG_A              NaN
# VEG_NRF            NaN
# VEG_U              NaN
# COV_NRF            NaN
# COV_RF             NaN
# COV_E              NaN
# EAST1              NaN
# NORTH1             NaN
# ZONE                15
# ACCUR1             NaN
# METHOD               G
# EAST2              NaN
# NORTH2             NaN
# ACCUR2             NaN
# ZONE_U              15
# EAST_U          727107
# NORTH_U        4671700
# GRIDCODE           NaN
# EAST_15            NaN
# NORTH_15           NaN
# HABITAT1           NaN
# HABITAT2           NaN
# HABITAT3           NaN
# HABITAT4           NaN
# HABITAT5           NaN
# HABITAT6           NaN
# DEPTH1             NaN
# DEPTH2             NaN
# DEPTH3             NaN
# DEPTH4             NaN
# DEPTH5             NaN
# DEPTH6             NaN
# DENSITY1           NaN
# DENSITY2           NaN
# DENSITY3           NaN
# DENSITY4           NaN
# DENSITY5           NaN
# DENSITY6           NaN
# BATCHNUM          2608
# SPPCD           NOSMPL
# VISUAL1              0
# VISUAL2              0
# VISUAL3              0
# VISUAL4              0
# VISUAL5              0
# VISUAL6              0
# RAKE1                1
# RAKE2                1
# RAKE3                1
# RAKE4                1
# RAKE5                1
# RAKE6                1
# ADDSPP             NaN
# COVSPP             NaN
# QECODE             NaN
# VOUCHER            NaN
# Name: 120098, dtype: object
# BARCODE       33011007
# ROWNUM               1
# PAGENUM              1
# FLDNUM               3
# PROJCD           M-98A
# POOL                13
# DATE        07/29/2013
# LDRCODE            501
# RCRDCODE           319
# DETRITUS           NaN
# SBSTRATE           NaN
# SITECD              94
# MSTRATUM            SC
# ASTRATUM           NaN
# RIVMILE           M544
# VEG_S              NaN
# VEG_RF             NaN
# VEG_E              NaN
# VEG_A              NaN
# VEG_NRF            NaN
# VEG_U              NaN
# COV_NRF            NaN
# COV_RF             NaN
# COV_E              NaN
# EAST1              NaN
# NORTH1             NaN
# ZONE                15
# ACCUR1             NaN
# METHOD               G
# EAST2              NaN
# NORTH2             NaN
# ACCUR2             NaN
# ZONE_U              15
# EAST_U          727357
# NORTH_U        4671600
# GRIDCODE           NaN
# EAST_15            NaN
# NORTH_15           NaN
# HABITAT1           NaN
# HABITAT2           NaN
# HABITAT3           NaN
# HABITAT4           NaN
# HABITAT5           NaN
# HABITAT6           NaN
# DEPTH1             NaN
# DEPTH2             NaN
# DEPTH3             NaN
# DEPTH4             NaN
# DEPTH5             NaN
# DEPTH6             NaN
# DENSITY1           NaN
# DENSITY2           NaN
# DENSITY3           NaN
# DENSITY4           NaN
# DENSITY5           NaN
# DENSITY6           NaN
# BATCHNUM          2608
# SPPCD           NOSMPL
# VISUAL1              0
# VISUAL2              0
# VISUAL3              0
# VISUAL4              0
# VISUAL5              0
# VISUAL6              0
# RAKE1                0
# RAKE2                0
# RAKE3                0
# RAKE4                0
# RAKE5                0
# RAKE6                0
# ADDSPP             NaN
# COVSPP             NaN
# QECODE             NaN
# VOUCHER            NaN
# Name: 120099, dtype: object

# %%
# Merge the latitude, longitude values to their respective DataFrames
df_water_output = df_water.merge(temp_water, left_on='SHEETBAR', right_on='SHEETBAR')
df_veg_output = df_veg.merge(temp_veg, left_on='BARCODE', right_on='BARCODE')

# Drop duplicates created via merge, needs debug
df_water_output = df_water_output.drop_duplicates()
df_veg_output = df_veg_output.drop_duplicates()

# %%
df_veg_output.shape
# Out:
# (125063, 76)

# %%
# Paths to export data as .csv
water_output_path = r'C:\Users\Doug\Documents\Classes\TDA\ltrm_water_data_lat_long.csv'
veg_output_path = r'C:\Users\Doug\Documents\Classes\TDA\ltrm_vegsrs_data_lat_long.csv'


df_water_output.to_csv(water_output_path,index=False)
df_veg_output.to_csv(veg_output_path,index=False)
